# %%
# !pip install pymupdf
# !pip install tabula-py

from operator import itemgetter
import fitz
import json
import numpy as np
import math
import tabula
import re
import pprint
import os


def fonts(doc, granularity=False):
    """Extracts fonts and their usage in PDF documents.

    :param doc: PDF document to iterate through
    :type doc: <class 'fitz.fitz.Document'>
    :param granularity: also use 'font', 'flags' and 'color' to discriminate text
    :type granularity: bool

    :rtype: [(font_size, count), (font_size, count}], dict
    :return: most used fonts sorted by count, font style information
    """
    styles = {}
    font_counts = {}

    for page in doc:
        blocks = page.get_text("dict")["blocks"]
        for b in blocks:  # iterate through the text blocks
            if b['type'] == 0:  # block contains text
                for l in b["lines"]:  # iterate through the text lines
                    for s in l["spans"]:  # iterate through the text spans
                        if granularity:
                            identifier = "{0}_{1}_{2}_{3}".format(s['size'], s['flags'], s['font'], s['color'])
                            styles[identifier] = {'size': s['size'], 'flags': s['flags'], 'font': s['font'],
                                                  'color': s['color']}
                        else:
                            identifier = "{0}".format(s['size'])
                            styles[identifier] = {'size': s['size'], 'font': s['font']}

                        font_counts[identifier] = font_counts.get(identifier, 0) + 1  # count the fonts usage

    font_counts = sorted(font_counts.items(), key=itemgetter(1), reverse=True)

    if len(font_counts) < 1:
        raise ValueError("Zero discriminating fonts found!")

    return font_counts, styles


def get_deviation(inp_data, p_size):
    """Returns deviation from the given value(para_size)
    """
    data = np.array(inp_data)
    n = len(data)
    # mean = sum(data) / n
    deviations = [(x - p_size) ** 2 for x in data]
    variance = sum(deviations) / n
    std_dev = round(math.sqrt(variance),2)
    # print(std_dev)
    return std_dev


def font_tags(font_counts, styles):
    """Returns dictionary with font sizes as keys and tags as value.

    :param font_counts: (font_size, count) for all fonts occuring in document
    :type font_counts: list
    :param styles: all styles found in the document
    :type styles: dict

    :rtype: dict
    :return: all element tags based on font-sizes
    """
    p_style = styles[font_counts[0][0]]  # get style for most used font by count (paragraph)
    p_size = p_style['size']  # get the paragraph's size

    # sorting the font sizes high to low, so that we can append the right integer to each tag
    font_sizes = []
    for (font_size, count) in font_counts:
        font_sizes.append(float(font_size))
    font_sizes.sort(reverse=True)
    dev_font_sizes = get_deviation(font_sizes, p_size)
    # aggregating the tags for each font size
    idx = 0
    size_tag = {}
    for size in font_sizes:
        idx += 1
        if size == p_size:
            idx = 0
            size_tag[size] = 'para'
        if size > p_size:
          if size - p_size < dev_font_sizes :
              size_tag[size] = 'para'
          else:
              if idx in (0,1):
                  size_tag[size] = 'header/title'
              else:
                size_tag[size] = 'sub-title'
        elif size < p_size:
            if p_size - size < dev_font_sizes :
                size_tag[size] = 'para'
            else:
                size_tag[size] = 's'
    return size_tag


def check_footers(blocks, size_tag):
    """Checks for footers
    """
    footers = []
    len_blocks = len(blocks)
    for index,b in enumerate(blocks[::-1]):
        if b['type'] == 0:
            for l in b["lines"]:
                for s in l["spans"]:
                    if s['text'].strip():
                        if "s" in size_tag[s['size']]:
                            footers.append(len_blocks - index - 1)
                        else:
                            return footers
                    else:
                        return footers

def extract_tables_from_pdf(pdf_path, pages="all"):
    """ Extract all tables from the PDF
    """
    tables = []
    extracted_tables = tabula.read_pdf(pdf_path, pages=pages, multiple_tables=True)
    if extracted_tables:
      tables = extracted_tables
    return tables


pattern_heading = "^\d+[)\.\sa-zA-Z0-9]+\\n"  # Like 1. Header, 1) Header, 1 header, etc
pattern_subheading = "^(\d+\.\d+[\)\.]?\s*)(.+)\n"  # Like 1.1 Header, 1.2) Header, 1.4. header, etc


def extract_elements(doc, size_tag, out_folder, doc_path):
    """Scrapes headers & paragraphs from PDF and return texts with element tags.

    :param doc: PDF document to iterate through
    :type doc: <class 'fitz.fitz.Document'>
    :param size_tag: textual element tags for each size
    :type size_tag: dict

    :rtype: list
    :return: texts with pre-prended element tags
    """
    elements = []
    first = True  # boolean operator for first header
    previous_s = {}  # previous span
    for page_number, page in enumerate(doc):

        # Extracting images
        images = page.get_images(full=True)
        for img_index, img in enumerate(images):
            xref = img[0]  # The image reference
            base_image = doc.extract_image(xref)
            image_bytes = base_image["image"]
            image_ext = base_image["ext"]  # Image format (e.g., 'png', 'jpeg')

            # Save the extracted image
            image_filename = f"page_{page_number+1}_image_{img_index + 1}.{image_ext}"
            image_file_path = os.path.join(out_folder, image_filename)
            with open(image_file_path, "wb") as image_file:
                image_file.write(image_bytes)
            element= {"type": "image",
                       "text": image_file_path,
                       "page": page_number + 1}
            elements.append(element)

        # Extracting tables
        extracted_tables = extract_tables_from_pdf(doc_path, pages=(page_number + 1,))
        for i, table in enumerate(extracted_tables):
            # Save each table as a CSV file
            csv_file_name = f"page_{page_number+1}_table_{i+1}.csv"
            csv_file_path = os.path.join(out_folder, csv_file_name)
            table.to_csv(csv_file_path, index=False)
            # print(f"Extracted table {i+1}")
            element= {"type": "table",
                       "text": csv_file_path,
                       "page": page_number + 1}
            elements.append(element)

        # Extracting text elements
        blocks = page.get_text("dict")["blocks"]
        # checking if footer is present
        footer_indexes = check_footers(blocks, size_tag)
        for index,b in enumerate(blocks):  # iterate through the text blocks
            if b['type'] == 0:  # this block contains text
                block_string = ""  # text found in block
                for l in b["lines"]:  # iterate through the text lines
                    for s in l["spans"]:  # iterate through the text spans
                        if s['text'].strip():  # removing whitespaces:
                            if first:
                                previous_s = s
                                first = False
                                block_size_tag = size_tag[s['size']]
                                block_string = s['text']
                            else:
                                if s['size'] == previous_s['size']:
                                    if block_string and all((c == "|") for c in block_string):
                                        # block_string only contains pipes
                                        block_size_tag = size_tag[s['size']]
                                        if "s" in block_size_tag and index in footer_indexes:
                                            block_size_tag = "footer"
                                        elif block_size_tag in ("sub-title", "header/title"):
                                            if len(s['text']) > 60:
                                                block_size_tag = "para"
                                            elif re.match(pattern_subheading, s['text']):
                                                block_size_tag = "sub-heading"
                                            elif re.match(pattern_heading, s['text']):
                                                block_size_tag = "heading"
                                            else:
                                                block_size_tag = "para"
                                        elif block_size_tag == "para" and len(s['text']) < 60:
                                            block_size_tag = "sub-title"
                                        block_string = s['text']
                                    if block_string == "":
                                        # new block has started, so append size tag
                                        block_size_tag = size_tag[s['size']]
                                        if "s" in block_size_tag and index in footer_indexes:
                                            block_size_tag = "footer"
                                        elif block_size_tag in ("sub-title", "header/title"):
                                            if len(s['text']) > 60:
                                                block_size_tag = "para"
                                            elif re.match(pattern_subheading, s['text']):
                                                block_size_tag = "sub-heading"
                                            elif re.match(pattern_heading, s['text']):
                                                block_size_tag = "heading"
                                            else:
                                                block_size_tag = "para"
                                        elif block_size_tag == "para" and len(s['text']) < 60:
                                            block_size_tag = "other"
                                        block_string = s['text']
                                    else:  # in the same block, so concatenate strings
                                        block_string += " " + s['text']

                                else:
                                    if len(block_string) >= 4:
                                        element = {"type": block_size_tag,
                                                   "text": block_string,
                                                   "page": page_number + 1}
                                        elements.append(element)
                                        # if block_size_tag in element_dict:
                                        #     element_dict[block_size_tag].append(block_string)
                                        # else:
                                        #   element_dict[block_size_tag] = [block_string]
                                    # header_para.append(block_string)
                                    block_size_tag = size_tag[s['size']]
                                    if "s" in block_size_tag and index in footer_indexes:
                                            block_size_tag = "footer"
                                    elif block_size_tag in ("sub-title", "header/title"):
                                        if len(s['text']) > 60:
                                            block_size_tag = "para"
                                        elif re.match(pattern_subheading, s['text']):
                                            block_size_tag = "sub-heading"
                                        elif re.match(pattern_heading, s['text']):
                                            block_size_tag = "heading"
                                        else:
                                            block_size_tag = "para"
                                    elif block_size_tag == "para" and len(s['text']) < 60:
                                        block_size_tag = "other"
                                    block_string = s['text']

                                previous_s = s

                    # new block started, indicating with a pipe
                    # block_string += "|"
                if len(block_string) >= 4:
                    element = {"type": block_size_tag,
                                "text": block_string,
                                "page": page_number + 1}
                    elements.append(element)
    return elements


def is_pdf(file_path):
    # Check if the file has a PDF extension
    if not file_path.lower().endswith('.pdf'):
        return False

    # Check the PDF header
    try:
        with open(file_path, 'rb') as file:
            header = file.read(4)
            # The PDF header should start with %PDF
            return header == b'%PDF'
    except Exception:
        return False


def main(pdf_path):
    file_name = os.path.basename(pdf_path)
    doc = fitz.open(pdf_path)
    font_counts, styles = fonts(doc, granularity=False)
    size_tag = font_tags(font_counts, styles)
    output_folder_name = file_name.split(".")[0]
    if not os.path.exists(output_folder_name):
        os.mkdir(output_folder_name)
    elements = extract_elements(doc, size_tag, output_folder_name, pdf_path)
    elememts_dict = {"elements": elements}
    print(json.dumps(elememts_dict, indent=4))
    out_file = f"{output_folder_name}_elements.json"
    with open(out_file, 'w+') as json_file:
        json.dump(elememts_dict, json_file, indent=4)

if __name__ == "__main__":
    pdf_path = str(input("Enter the PDF filename(or press ENTER if filename is document.pdf):"))
    if not pdf_path:
        pdf_path = "document.pdf"
    if not is_pdf(pdf_path):
            print(f"Please give a valid pdf file as input")
    if not os.path.isfile(pdf_path):
        print(f"PDF file not found in current directory: {pdf_path}")
    else:
        main(pdf_path)
# Out:
# Requirement already satisfied: pymupdf in /usr/local/lib/python3.10/dist-packages (1.24.11)
# Requirement already satisfied: tabula-py in /usr/local/lib/python3.10/dist-packages (2.10.0)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.10/dist-packages (from tabula-py) (2.2.2)
# Requirement already satisfied: numpy>1.24.4 in /usr/local/lib/python3.10/dist-packages (from tabula-py) (1.26.4)
# Requirement already satisfied: distro in /usr/lib/python3/dist-packages (from tabula-py) (1.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->tabula-py) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->tabula-py) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.25.3->tabula-py) (1.16.0)
# Enter the PDF filename(or press ENTER if filename is document.pdf):2.pdf
# {
#     "elements": [
#         {
#             "type": "header/title",
#             "text": "Saudi Basic Industries Corporation (SABIC) ",
#             "page": 1
#         },
#         {
#             "type": "other",
#             "text": "Business Overview  SABIC is the largest Petrochemical company based out in Riyadh, Saudi Arabia. 70% of the company\u2019s shares are owned by  Saudi Aramco, with the remaining 30% publicly traded on the Saudi stock exchange. The company operates through three  Strategic Business Units \u2013 Petrochemicals, Specialities, and Agri-Nutrients and caters to businesses in key end markets  such as F&B, Building & Construction, Agriculture, Consumer Goods, transportation, Industrial Automotive, Electrical and  Electronics, & Pharmaceuticals.  ",
#             "page": 1
#         },
#         {
#             "type": "para",
#             "text": "The key strategic regions SABIC caters to are Saudi Arabia, China, Asia Pacific, and Europe contributing 15% to 20% each  as of Q3 2023. As of 2022, the company has generated revenues amounting to SAR 198 Bn and an annual production of 56  MM tons representing an increase of 13.5% and 5.6% respectively from 2021 levels.   ",
#             "page": 1
#         },
#         {
#             "type": "other",
#             "text": "Petrochemicals and Specialities ",
#             "page": 1
#         },
#         {
#             "type": "para",
#             "text": "Revenues rose from SAR 149.9 Bn in 2021 to SAR 164.8 Bn in 2022, representing a 10% increase, driven by a 7% jump in  sales volumes and a 3% hike in average sales prices. The production volumes and Sales volumes in 2022 stood at 47.9 KMT  and 39.9 KMT respectively, representing an increase of 4.5% and 7.12%. On a 9-month basis, SABIC reported a 23.5% drop  in revenues in 2023 as compared to 2022. We reckon the decline is mainly due to excess supply dampening the commodity  prices globally.  ",
#             "page": 1
#         },
#         {
#             "type": "para",
#             "text": "SABIC has partnered with Formula E to develop the GENBETA car, this revolutionary electric race car would draw on SABIC\u2019s  expanding portfolio of thermoplastics. SABIC has introduced bio-based versions of all NORYL resin grades to further  advance the bioeconomy of plastics. The broad range of physical properties of NORYL resins supports the needs of emerging  markets such as EV, Solar, Wind, and Batteries and essential industries including Water Management, Building and  Construction, and Automotive. The management believes that these innovations and partnerships with renowned  organizations will foster growth in the coming years for SABIC. ",
#             "page": 1
#         },
#         {
#             "type": "other",
#             "text": "Agri-Nutrients ",
#             "page": 1
#         },
#         {
#             "type": "para",
#             "text": "Revenues rose from SAR 12.2 Bn in 2021 to SAR 18.2 Bn in 2022, representing a 49.2% increase, driven by a 9% jump in  sales volumes and a 38% hike in average sales prices. The production volumes and Sales volumes in 2022 stood at 8.3 MM  MT and 6.7 MM MT respectively, representing an increase of 9.2% and 8.1%. On a 9-month basis, SABIC reported a 47.2%  drop in revenues in 2023 as compared to 2022. The decline was caused due to a 44% fall in the selling prices in Q3 2023 on  a YoY basis. ",
#             "page": 1
#         },
#         {
#             "type": "other",
#             "text": "Stock Performance  Over a one-year time frame, the company\u2019s stock price has witnessed a 14.25% decline. The stock is trading at SAR 79.6 as  of 27",
#             "page": 2
#         },
#         {
#             "type": "para",
#             "text": " Feb 2024. We believe the decline is mainly due to the margin contraction faced over the last 4 quarters due to product  prices falling faster than the feedstock prices. We have also noticed that the stock has seen huge spikes in volumes during  a downward price move, indicating a bearish signal on the stock. ",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "Macro-Economic Factors and Global Prices  Global economic growth is projected at 3.1% in 2024 and 3.2% in 2025, with the 2024 forecast 0.2 percentage points higher  than that in the October 2023 World Economic Outlook on account of greater-than-expected resilience in the United States  and several large emerging market and developing economies, as well as fiscal support in China. The forecast for 2024\u201325  is, however, below the historical (2000\u201319) average of 3.8%, with elevated central bank policy rates to fight inflation, a  withdrawal of fiscal support amid high debt weighing on economic activity, and low underlying productivity growth. Inflation  is falling faster than expected in most regions, amid unwinding supply-side issues and restrictive monetary policy. Global  headline inflation is expected to fall to 5.8% in 2024 and to 4.4% in 2025, with the 2025 forecast revised down.  China's economy faces a more challenging 2024, having expanded by 5.2% in real terms in 2023. There remain thorny issues  in the economy, including a continued downturn in the property sector, a debt overhang among local governments, elevated  youth unemployment, and deflationary pressures. Private consumption will be a major driver of growth, with the government  still relying heavily on public investments to realize its economic ambitions. IMF forecasts that real GDP growth will reach  4.6% in 2024 before decelerating further to 4.1% in 2025.  Following subdued growth last year, the EU economy has entered 2024 on a weaker footing than expected. The European  Commission's Winter Interim Forecast revises growth in both the EU and the euro area down to 0.5% in 2023, from 0.6%  projected in the Autumn Forecast, and to 0.9% (from 1.3%) in the EU and 0.8% (from 1.2%) in the euro area in 2024. In 2025,  economic activity is still expected to expand by 1.7% in the EU and 1.5% in the euro area. ",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "91.9",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "85.5",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "93.0",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "90.0",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "75.8",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "83.5",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "78.8",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": " 1,000",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": " 2,000",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": " 3,000",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": " 4,000",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": " 5,000",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": " 6,000",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "70.0",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "80.0",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "90.0",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "100.0",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "2/27/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "3/13/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "3/27/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "4/10/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "4/24/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "5/8/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "5/22/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "6/5/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "6/19/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "7/3/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "7/17/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "7/31/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "8/14/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "8/28/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "9/11/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "9/25/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "10/9/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "10/23/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "11/6/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "11/20/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "12/4/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "12/18/2023",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "1/1/2024",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "1/15/2024",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "1/29/2024",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "2/12/2024",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "2/26/2024",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "Thousands",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "Volumes SABIC Stock Prices",
#             "page": 2
#         },
#         {
#             "type": "other",
#             "text": "Exhibit 1 \u2013 Global GDP Growth % ",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "China\u2019s (Over)Capacity  China accounts for around 45% of the global demand for chemicals and petrochemicals. In 2022 China consumed almost  as much polyethylene as the rest of the developing world combined, despite having a population less than 30% of its size.  Following an end to the largest government stimulus package on record, and with weak export markets, an aging population,  and a decreasing household-forming demographic, demand began to contract. Growth in Chinese consumption across  most chemicals was in the low single digits or even negative in 2021 and 2022, despite widely being expected to be in the  high single digits, and this has contributed to the current oversupply.  Additionally, surplus chemicals capacity has been building in China since 2014, five years after the launch of a government  program to increase self-sufficiency in an industry perceived as high value. China currently accounts for 45% of global  chemical production capacity and anticipates achieving 62% market share by 2035, partly through export leadership but  also by focusing on innovative, greener products and higher-value specialty chemicals. In 2022, global overcapacity in the  six chemical building blocks averaged 191 MM MT (out of a market size of 2.3 Bn MT). That figure is expected to rise a further  10-15% by 2025 to 218MM MT.  Economies of scale have also led to China becoming a much larger producer of some fine and specialty chemicals such as  plastic additives. Given the reliance on plastic compounds as additives for their manufacture, this development will  significantly impact future supply chains and pricing.  Demand & Pricing  US-headquartered Dow recently said it expects challenging market conditions to persist through the fourth quarter but noted  some indications that things could improve next year as there seems to be an upward movement in the MEG\u2019s spot price  and polyester production rates in China being over 70%, despite witnessing a decrease in prices by 6% globally because of  higher supplies and new capabilities. Price is forecasted to increase due to escalating feedstock expenses and an increase  in crude oil prices, driven majorly by the packaging industry.  In Q4 2023, the North American and APAC methanol market remained healthy with market dynamics affected by a strong  upstream market, elevation in demand, and low inventory levels. There seems to be a bearish sentiment across the  European and MEA markets due to high supply, low demand, and low rate of product consumption. The Methanol prices in  Q3 2023 decreased by 8% globally and are expected to rise to USD 2,655 CNY/T by the end of 2024.  For MTBE, prices increased globally by 17% in Q3 2023 due to an improvement in demand from the driving season. Prices  for the commodity were reduced in Q4 2023 due to sufficient product availability and weak cost support from upstream  markets. According to ChemAnalyst, the price of MTBE in the global market will oscillate as per the fluctuations in the ",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "5.4 5.6",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "-0.1",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "-2.8",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "3 2.9  3.2",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2000",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2001",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2002",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2003",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2004",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2005",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2006",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2007",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2008",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2009",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2010",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2011",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2012",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2013",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2014",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2015",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2016",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2017",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2018",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2019",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2020",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2021",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2022",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2023",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2024",
#             "page": 3
#         },
#         {
#             "type": "other",
#             "text": "2025",
#             "page": 3
#         },
#         {
#             "type": "para",
#             "text": "Methanol market. In the Asian market, MTBE will remain plunged under the influence of a healthy influx of Methanol from  Saudi Arabia, reducing the production cost among enterprises.   Polyethylene prices decreased globally by 6% due to higher supply although prices in China were up by 1% supported by a  slight improvement in demand.   In the third quarter of 2023, the Middle Eastern Polypropylene (PP) market displayed a mixed pattern. Initially, the KSA PP  market experienced a 1.5% price decline primarily due to increased PP supply resulting from cheaper feedstock and weaker  demand attributed to the economic slowdown. Additionally, lower prices of PP substitutes further eroded its demand.  However, the latter part of the quarter saw a reversal, with PP prices increasing by 1.6% and 1.7% due to a bullish trend in  feedstock PP prices, closely linked to a 24% surge in Crude Oil prices. PP prices fell by 20.3% from 9,262 CNY/T in Feb 2021  to 7,380 CNY/T in Feb 2024. PP is expected to trade at 7,037.57 CNY/T in the next year.  Polycarbonate global prices decreased by 6% driven by lower government investments and weak recovery signals. In Q4  2023, PC witnessed bearish trends due to weakened demand from downstream industries and abundant supply. Prices are  expected to stabilize for the following year.   Feed Stock  Dated Brent prices are forecast to decline from USD 93/b in October to USD 81/b in March 2024, according to S&P Global  Commodity Insights, but with potential for volatility owing to geopolitical turmoil and economic uncertainties. Prices are  expected to rise after the first quarter of 2024. S&P Global's annual average forecast for Dated Brent is USD 85/b in 2024  and USD 76/b in 2025. Naphtha futures steadied around USD 660 per tonne, maintaining levels not seen in almost five  months, amidst growing concerns over supply due to escalating tensions in the Middle East. The ongoing Israel-Hamas  conflict shows no signs of resolution, while attacks by Houthi militants on vessels persist. Ukrainian strikes on Russian  refineries have also impacted one of the world's largest exporters, leading to a reduction of around a third in total exports.  Exhibit 2 \u2013 Brent Oil Futures ",
#             "page": 4
#         },
#         {
#             "type": "para",
#             "text": "Furthermore, US natural gas futures fell more than 6% toward USD 1.6/MMBtu on Friday, driven by abundant supply, ample  storage, and reduced heating demand amid a mild winter. Despite an Arctic freeze in January briefly impacting output, record  levels have been maintained. Mild weather has left stockpiles well above normal, with the latest EIA data revealing storage  22.3% above the seasonal norm. Propane prices held near USD 0.9 per gallon, like an almost 1-1/2 year high recorded on  February 1st, as demand remained strong and missile attacks in the Middle East fuelled concerns about shipments.  According to the latest EIA report, the US propane inventories dropped to 54.6 MM barrels on the week of February 16th,  down from 63.3 MM barrels in the same period a year earlier and marking the softest reading since the end of June 2022. ",
#             "page": 4
#         },
#         {
#             "type": "other",
#             "text": "92.16",
#             "page": 4
#         },
#         {
#             "type": "other",
#             "text": "83.03",
#             "page": 4
#         },
#         {
#             "type": "other",
#             "text": "2/24/23 3/24/23 4/24/23 5/24/23 6/24/23 7/24/23 8/24/23 9/24/23 10/24/23 11/24/23 12/24/23 1/24/24",
#             "page": 4
#         },
#         {
#             "type": "image",
#             "text": "2/page_5_image_1.png",
#             "page": 5
#         },
#         {
#             "type": "image",
#             "text": "2/page_5_image_2.png",
#             "page": 5
#         },
#         {
#             "type": "image",
#             "text": "2/page_5_image_3.png",
#             "page": 5
#         },
#         {
#             "type": "table",
#             "text": "2/page_5_table_1.csv",
#             "page": 5
#         },
#         {
#             "type": "other",
#             "text": "Exhibit 3 \u2013 Naphtha Futures ",
#             "page": 5
#         },
#         {
#             "type": "other",
#             "text": "Exhibit 4 \u2013 Natural Gas Futures ",
#             "page": 5
#         },
#         {
#             "type": "other",
#             "text": "Exhibit 5 \u2013 Propane Futures ",
#             "page": 5
#         },
#         {
#             "type": "other",
#             "text": "Key Financials  ",
#             "page": 5
#         },
#         {
#             "type": "other",
#             "text": "Income Statement  (SAR MM) 2018  2019  2020  2021  2022  LTM - Sep 23  2023  2024  2025  2026  2027 ",
#             "page": 5
#         },
#         {
#             "type": "other",
#             "text": "Revenue  169.1   135.4   116.9   174.9   198.5   161.4   145.7   149.5   160.6   172.0   179.0  ",
#             "page": 5
#         },
#         {
#             "type": "other",
#             "text": "YoY Growth %  (19.9%)  (13.6%)  49.5%   13.5%   (18.7%)  (9.7%)  2.6%   7.4%   7.1%   4.0%  ",
#             "page": 5
#         },
#         {
#             "type": "other",
#             "text": "COGS  (111.3)  (106.0)  (94.3)  (127.0)  (155.8)  (136.9)  (131.7)  (135.6)  (144.1)  (150.6)  (154.4) ",
#             "page": 5
#         },
#         {
#             "type": "other",
#             "text": "Gross Profit  57.8   29.4   22.6   47.9   42.7   24.6   14.0   13.9   16.5   21.4   24.6  ",
#             "page": 5
#         },
#         {
#             "type": "other",
#             "text": "Margin %  34.2%   21.7%   19.4%   27.4%   21.5%   15.2%   9.6%   9.3%   10.3%   12.4%   13.7%  ",
#             "page": 5
#         },
#         {
#             "type": "other",
#             "text": "Operating Expense  (5.4)  1.0   (2.2)  0.6   (4.1)  (18.0)  (1.1)  0.8   1.9   2.0   2.0  ",
#             "page": 5
#         },
#         {
#             "type": "other",
#             "text": "Depreciation & Amortization  (15.5)  (18.4)  (15.9)  (14.9)  (14.7)  -   (14.8)  (14.4)  (15.4)  (16.4)  (17.1) ",
#             "page": 5
#         },
#         {
#             "type": "other",
#             "text": "Total Operating Expense  (20.9)  (17.5)  (18.1)  (14.3)  (18.8)  (18.0)  (15.9)  (13.6)  (13.5)  (14.5)  (15.0) ",
#             "page": 5
#         },
#         {
#             "type": "other",
#             "text": "
",
#             "page": 7
#         },
#         {
#             "type": "other",
#             "text": "Total Liabilities & Shareholders' Equity  308.5   300.5   295.5   319.4   313.1   299.3   286.1   283.3   284.8   285.6   287.7  ",
#             "page": 7
#         },
#         {
#             "type": "para",
#             "text": "At a perpetual growth rate of 3% and a discount rate of 8.6%, we have arrived at a price of SAR 66.8. The stock is currently  trading at SAR 79.6, and we believe that the stock could further correct by around 16% to 20% trading at a range of SAR 62.5  to SAR 66.8. We could also see the stock trading at around SAR 70 to SAR 75 over the next few quarters provided global  prices stabilize, however, still below the current price levels.  ",
#             "page": 7
#         },
#         {
#             "type": "other",
#             "text": "Our Analysis & Recommendations  With disinflation and steady growth, the likelihood of a hard landing has receded, and risks to global growth are broadly  balanced. On the upside, faster disinflation could lead to further easing of financial conditions. Looser fiscal policy than  necessary and then assumed in the projections could imply temporarily higher growth but at the risk of a more costly  adjustment later. Stronger structural reform momentum could bolster productivity with positive cross-border spillovers. On  the downside, new commodity price spikes from geopolitical shocks\u2013\u2013including continued attacks in the Red Sea\u2013\u2013and  supply disruptions or more persistent underlying inflation could prolong tight monetary conditions.   Price decreases in Glycol, PE, PVC, and PP over the last two years are mainly due to geo-political shocks and excess supply  worldwide. The average decline witnessed in these prices was around 11.8% and 5.9% in 2022 and 2023 respectively.  Economists expect a decline of around 1.0% over the next 12 months. We anticipate headwinds to continue for the next  year, and then anticipate a recovery in global prices over the medium and long term.  Urea prices surged in Q3 2023 mainly due to production disruptions leading to supply shortages and rising demand for urea.  However, based on the World Bank, Urea prices will decline by 13% in 2024 as production recovers. DAP prices fell by 5%  in 2023 Q3 relative to the previous quarter and dropped nearly 34% over the past year because of the decrease in the price  of natural gas. As per the World Bank, DAP prices are expected to fall further in 2024 and 2025 as supplies recover and  capacity strengthens. Potassium Chloride prices decreased by 6% in 2023 Q3 relative to the previous quarter and remained  more than 60% lower than in 2022 Q3, impacted by sanctions on Belarus and Russia. After an estimated 55% decline in  2023, Potassium Chloride prices are expected to drop another 22% in 2024 before stabilizing in 2025. ",
#             "page": 7
#         },
#         {
#             "type": "para",
#             "text": "With global prices of Chemicals and Agri-nutrients witnessing downward pressures due to overcapacity and excess supply,  which is likely to have spillover effects over the next few quarters as well, we anticipate a ~20% decline in SABIC\u2019s revenues  in 2023 and a marginal uptake in 2024. Additionally, with feedstock prices expected to decrease, however, at a slower rate  as compared to Chemicals and Agri-nutrients prices, we expect SABIC will witness margin contraction in the short term. ",
#             "page": 7
#         },
#         {
#             "type": "para",
#             "text": "Given the global macroeconomic factors and demand\u2013supply and price factors, we believe that SABIC is overvalued by  around 16%. We value SABIC\u2019s share at SAR 66.8 ",
#             "page": 7
#         },
#         {
#             "type": "other",
#             "text": "Discount Rate",
#             "page": 7
#         },
#         {
#             "type": "other",
#             "text": "2.40% 2.60% 2.80% 3.00% 3.20% 3.40%",
#             "page": 7
#         },
#         {
#             "type": "other",
#             "text": "6.76% 87.9 91.6 95.7 100.3 105.3 110.9",
#             "page": 7
#         },
#         {
#             "type": "other",
#             "text": "7.38% 76.8 79.6 82.6 85.9 89.5 93.5",
#             "page": 7
#         },
#         {
#             "type": "other",
#             "text": "8.00% 68.2 70.4 72.7 75.1 77.8 80.8",
#             "page": 7
#         },
#         {
#             "type": "other",
#             "text": "8.62% 61.3 63.0 64.8 66.8 68.8 71.1",
#             "page": 7
#         },
#         {
#             "type": "other",
#             "text": "9.00% 57.7 59.2 60.8 62.5 64.3 66.2",
#             "page": 7
#         },
#         {
#             "type": "other",
#             "text": "9.38% 54.5 55.8 57.2 58.7 60.3 61.9",
#             "page": 7
#         },
#         {
#             "type": "other",
#             "text": "9.76% 51.7 52.8 54.1 55.4 56.7 58.2",
#             "page": 7
#         },
#         {
#             "type": "other",
#             "text": "Perpetual Growth Rate",
#             "page": 7
#         }
#     ]
# }
